# %% [markdown]
# <a href="https://www.kaggle.com/code/chandruuk/top-video-games-1995-2021-metacritic?scriptVersionId=105719819" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-video-games-19952021-metacritic/all_games.csv

# %%
data=pd.read_csv("/kaggle/input/top-video-games-19952021-metacritic/all_games.csv")

# %%
data.head(10)
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
# 5                    Super Mario Galaxy             Wii   November 12, 2007
# 6                  Super Mario Galaxy 2             Wii        May 23, 2010
# 7                 Red Dead Redemption 2        Xbox One    October 26, 2018
# 8                    Grand Theft Auto V        Xbox One   November 18, 2014
# 9                    Grand Theft Auto V   PlayStation 3  September 17, 2013
#
#                                              summary  meta_score user_review
# ...

# %%
data.shape
# Out:
# (18800, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18800 entries, 0 to 18799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18800 non-null  object
#  1   platform      18800 non-null  object
#  2   release_date  18800 non-null  object
#  3   summary       18686 non-null  object
#  4   meta_score    18800 non-null  int64
#  5   user_review   18800 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 881.4+ KB

# %%
str="Not Available"
data['summary'].fillna("Not Available", inplace = True)

# %%
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Analysising the Dataset

# %%
data.describe()
# Out:
#          meta_score
# count  18800.000000
# mean      70.648883
# std       12.225006
# min       20.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max       99.000000

# %% [markdown]
# **Top Games**

# %%
data.sort_values(by=['meta_score','user_review'], ascending=False).head(5)
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
#
#                                              summary  meta_score user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 1  As most major publishers' development efforts ...          98         7.4

# %%
data.head(5)
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score user_review
# 0  As a young boy, Link is tricked by Ganondorf, ...          99         9.1
# 1  As most major publishers' development efforts ...          98         7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98         7.7
# 3  This is a tale of souls and swords, transcendi...          98         8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98         7.9

# %%
dfvalued=data.groupby("platform", as_index=False).meta_score.mean()
print(" top 10 most meat score of platform")
dfvalued.sort_values(by="meta_score",ascending=False).head(10)
# Out:
#  top 10 most meat score of platform
#              platform  meta_score
# 5         Nintendo 64   78.436620
# 21      Xbox Series X   75.987013
# 12      PlayStation 5   75.427419
# 2           Dreamcast   74.072000
# 8         PlayStation   73.342246
# 15             Switch   72.523231
# 17              Wii U   72.423913
# 20           Xbox One   72.395250
# 6                  PC   71.797903
# 13   PlayStation Vita   71.062257

# %%
dfvalued=data.groupby(['name','platform','user_review'],as_index=False).meta_score.max()
print("Highest review game in each Platform")
dfvalued.sort_values(by="meta_score",ascending=False).head(10)
# Out:
# Highest review game in each Platform
#                                        name        platform user_review  \
# 15938  The Legend of Zelda: Ocarina of Time     Nintendo 64         9.1
# 6306                    Grand Theft Auto IV   PlayStation 3         7.7
# 6307                    Grand Theft Auto IV        Xbox 360         7.9
# 14006                           SoulCalibur       Dreamcast         8.4
# 16919              Tony Hawk's Pro Skater 2     PlayStation         7.4
# 6581                   Halo: Combat Evolved            Xbox         8.7
# 16925              Tony Hawk's Pro Skater 3   PlayStation 2         7.5
# 10131                               NFL 2K1       Dreamcast         6.2
# 9291                          Metroid Prime        GameCube         8.6
# 3896           Disco Elysium: The Final Cut              PC         8.3
#
#        meta_score
# 15938          99
# 6306           98
# 6307           98
# 14006          98
# 16919          98
# 6581           97
# ...

# %%
print( data['platform'].value_counts())
# Out:
#  PC                  4864
#  PlayStation 4       2056
#  Xbox 360            1644
#  PlayStation 2       1414
#  Switch              1399
#  PlayStation 3       1256
#  Xbox One            1179
#  Xbox                 789
#  DS                   720
#  Wii                  655
#  PSP                  512
#  GameCube             448
#  Game Boy Advance     438
#  3DS                  396
#  PlayStation Vita     257
#  PlayStation          187
#  Wii U                184
#  Dreamcast            125
#  PlayStation 5        124
#  Xbox Series X         77
#  Nintendo 64           71
#  Stadia                 5
# Name: platform, dtype: int64

# %%
data["year"] = [x.split(",")[1] for x in data["release_date"].values]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.express as px

long_df = data



fig = px.bar(data, x="platform", y="year", color="meta_score", title="Each year meta score by platfrom")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
